# %% [markdown]
# Nilas Myler (153839), Miaomiao Yuan (176835) & Ya-Wen Liang (176692)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

file_path = 'ML Final final/Sales Transaction.csv'

df_raw = pd.read_csv(file_path)

# %%
# Display the first few rows and some basic info
print("First 5 rows of the raw dataset:")
print(df_raw.head())
print("\nDataset Information:")
df_raw.info()
# Out:
# First 5 rows of the raw dataset:
#   TransactionNo        Date ProductNo                          ProductName  \
# 0        581482  12-09-2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12-09-2019     22596  Christmas Star Wish List Chalkboard
# 2        581475  12-09-2019     23235             Storage Tin Vintage Leaf
# 3        581475  12-09-2019     23272    Tree T-Light Holder Willie Winkie
# 4        581475  12-09-2019     23239    Set Of 4 Knick Knack Tins Poppies
#
#    Price  Quantity  CustomerNo         Country
# 0  21.47        12     17490.0  United Kingdom
# 1  10.65        36     13069.0  United Kingdom
# 2  11.53        12     13069.0  United Kingdom
# 3  10.65        12     13069.0  United Kingdom
# 4  11.94         6     13069.0  United Kingdom
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536350 entries, 0 to 536349
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TransactionNo  536350 non-null  object
#  1   Date           536350 non-null  object
#  2   ProductNo      536350 non-null  object
#  3   ProductName    536350 non-null  object
#  4   Price          536350 non-null  float64
#  5   Quantity       536350 non-null  int64
#  6   CustomerNo     536295 non-null  float64
#  7   Country        536350 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.7+ MB

# %%
print(" Descriptive Statistics:")
df_raw.describe(include='all')
# Out:
#  Descriptive Statistics:
#        TransactionNo        Date ProductNo  \
# count         536350      536350    536350
# unique         23204         305      3768
# top           573585  12-05-2019    85123A
# freq            1111        5299      2378
# mean             NaN         NaN       NaN
# std              NaN         NaN       NaN
# min              NaN         NaN       NaN
# 25%              NaN         NaN       NaN
# 50%              NaN         NaN       NaN
# 75%              NaN         NaN       NaN
# max              NaN         NaN       NaN
#
#                                ProductName          Price       Quantity  \
# count                               536350  536350.000000  536350.000000
# unique                                3768            NaN            NaN
# top     Cream Hanging Heart T-Light Holder            NaN            NaN
# freq                                  2378            NaN            NaN
# mean                                   NaN      12.662182       9.919347
# std                                    NaN       8.490450     216.662300
# min                                    NaN       5.130000  -80995.000000
# 25%                                    NaN      10.990000       1.000000
# 50%                                    NaN      11.940000       3.000000
# 75%                                    NaN      14.090000      10.000000
# max                                    NaN     660.620000   80995.000000
#
#            CustomerNo         Country
# count   536295.000000          536350
# unique            NaN              38
# top               NaN  United Kingdom
# freq              NaN          485095
# mean     15227.893178             NaN
# std       1716.582932             NaN
# min      12004.000000             NaN
# 25%      13807.000000             NaN
# 50%      15152.000000             NaN
# 75%      16729.000000             NaN
# max      18287.000000             NaN

# %%
# Convert 'Date' column to datetime objects

df_raw['Date'] = pd.to_datetime(df_raw['Date'], dayfirst=True, errors='coerce')

# %%
# Ensure 'Price' and 'Quantity' are numeric and handle potential issues
df_raw['Price'] = pd.to_numeric(df_raw['Price'], errors='coerce')
df_raw['Quantity'] = pd.to_numeric(df_raw['Quantity'], errors='coerce')

# %%
# Handle missing and negative values

print(f"\nNumber of rows before cleaning NAs and negatives: {len(df_raw)}")
df_raw = df_raw[df_raw['Quantity'] > 0]
df_raw = df_raw[df_raw['Price'] > 0]
print(f"\nNumber of rows after cleaning NAs and negatives: {len(df_raw)}")
# Out:
# Number of rows before cleaning NAs and negatives: 536350
#
# Number of rows after cleaning NAs and negatives: 527765

# %%
# Ensure CustomerNo is treated as an string to exclude it from math operations
if pd.api.types.is_numeric_dtype(df_raw['CustomerNo']):
    df_raw['CustomerNo'] = df_raw['CustomerNo'].astype(str)

# %%
print("\nUnique values per column (after initial cleaning):")
for col in df_raw.columns:
    print(f"- {col}: {df_raw[col].nunique()} unique values")

print("\nValue counts for 'Country':")
print(df_raw['Country'].value_counts().head(10)) # Display top 10 countries
# Out:
# Unique values per column (after initial cleaning):
# - TransactionNo: 19790 unique values
# - Date: 127 unique values
# - ProductNo: 3753 unique values
# - ProductName: 3753 unique values
# - Price: 514 unique values
# - Quantity: 375 unique values
# - CustomerNo: 4719 unique values
# - Country: 38 unique values
#
# Value counts for 'Country':
# Country
# United Kingdom    477771
# France             10393
# Germany            10240
# EIRE                7807
# Belgium             2507
# Spain               2386
# Netherlands         2326
# Switzerland         2303
# Portugal            1838
# Australia           1631
# Name: count, dtype: int64

# %%
# Time period of the dataset
print(f"\nDataset time period: {df_raw['Date'].min()} to {df_raw['Date'].max()}")
print(f"Duration: {df_raw['Date'].max() - df_raw['Date'].min()}")
# Out:
# Dataset time period: 2018-01-12 00:00:00 to 2019-12-10 00:00:00
# Duration: 697 days 00:00:00

# %% [markdown]
# Group/aggregate by transaction

# %%
# Calculate total value for each product line
df_raw['LineTotal'] = df_raw['Price'] * df_raw['Quantity']

# %%
# Define aggregation functions
aggregations = {
    'LineTotal': 'sum',                    # Total value of the transaction
    'Quantity': 'sum',                     # Total number of items in the transaction
    'ProductNo': 'nunique',                # Number of unique products in the transaction
    'Price': ['mean', 'min', 'max'],       # Avg, min, max price of items in transaction
    'CustomerNo': 'first',                 # one customer per transaction
    'Country': 'first',                    # one country per transaction
    'Date': 'first'                        # transaction date (assuming all items in a transaction share the same date)
}

# %%
# Group by TransactionNo and apply aggregations
df_transactions = df_raw.groupby('TransactionNo').agg(aggregations)

# %%
df_transactions.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in df_transactions.columns.values]
df_transactions.rename(columns={
    'LineTotal_sum': 'TotalTransactionValue',
    'Quantity_sum': 'TotalItemsInTransaction',
    'ProductNo_nunique': 'UniqueProductsInTransaction',
    'Price_mean': 'AvgItemPriceInTransaction',
    'Price_min': 'MinItemPriceInTransaction',
    'Price_max': 'MaxItemPriceInTransaction',
    'CustomerNo_first': 'CustomerNo',
    'Country_first': 'Country',
    'Date_first': 'TransactionDate'
}, inplace=True)

# %%
df_transactions.head(5)
# Out:
#                TotalTransactionValue  TotalItemsInTransaction  \
# TransactionNo
# 536365                        552.52                       40
# 536366                        145.80                       12
# 536367                       1136.34                       83
# 536368                        225.54                       15
# 536369                         49.05                        3
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# TransactionNo
# 536365                                   7                  14.255714
# 536366                                   2                  12.150000
# 536367                                  12                  15.224167
# 536368                                   4                  15.142500
# 536369                                   1                  16.350000
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction  \
# TransactionNo
# 536365                             12.86                      18.09
# 536366                             12.15                      12.15
# 536367                             11.94                      20.45
# 536368                             14.61                      15.32
# 536369                             16.35                      16.35
#
#               CustomerNo         Country TransactionDate
# TransactionNo
# 536365           17850.0  United Kingdom      2018-01-12
# 536366           17850.0  United Kingdom      2018-01-12
# 536367           13047.0  United Kingdom      2018-01-12
# 536368           13047.0  United Kingdom      2018-01-12
# 536369           13047.0  United Kingdom      2018-01-12

# %%
df_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19790 entries, 536365 to 581587
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   TotalTransactionValue        19790 non-null  float64
#  1   TotalItemsInTransaction      19790 non-null  int64
#  2   UniqueProductsInTransaction  19790 non-null  int64
#  3   AvgItemPriceInTransaction    19790 non-null  float64
#  4   MinItemPriceInTransaction    19790 non-null  float64
#  5   MaxItemPriceInTransaction    19790 non-null  float64
#  6   CustomerNo                   19790 non-null  object
#  7   Country                      19790 non-null  object
#  8   TransactionDate              8486 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
#reduce floats to 2 in display for easier reading
df_transactions.describe()
# Out:
#        TotalTransactionValue  TotalItemsInTransaction  \
# count           1.979000e+04             19790.000000
# mean            3.181707e+03               282.541587
# min             5.460000e+00                 1.000000
# 25%             8.301600e+02                71.000000
# 50%             1.717000e+03               153.000000
# 75%             3.312035e+03               298.000000
# max             1.002718e+06             80995.000000
# std             1.126961e+04               962.577651
#
#        UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# count                 19790.000000               19790.000000
# mean                     26.116726                  13.094252
# min                       1.000000                   5.460000
# 25%                       6.000000                  11.555040
# 50%                      15.000000                  12.693705
# 75%                      29.000000                  13.991708
# max                    1104.000000                 660.620000
# std                      46.912121                  13.836818
#
#        MinItemPriceInTransaction  MaxItemPriceInTransaction  \
# count               19790.000000               19790.000000
# mean                    9.751900                  20.699754
# min                     5.130000                   5.460000
# 25%                     6.130000                  14.090000
# 50%                    10.550000                  18.400000
# 75%                    11.120000                  23.060000
# max                   660.620000                 660.620000
# std                    13.111079                  31.785496
#
#                      TransactionDate
# count                           8486
# mean   2019-05-11 17:37:51.317464320
# min              2018-01-12 00:00:00
# 25%              2019-03-02 00:00:00
# 50%              2019-06-07 00:00:00
# 75%              2019-09-06 00:00:00
# max              2019-12-10 00:00:00
# std                              NaN

# %%
# Set style for plots
sns.set(style="whitegrid")

# Features to visualize
numerical_features = ['TotalTransactionValue', 'TotalItemsInTransaction', 'UniqueProductsInTransaction',
                      'AvgItemPriceInTransaction', 'MinItemPriceInTransaction', 'MaxItemPriceInTransaction']

# %%
# Create histograms
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_features):
    plt.subplot(2, 3, i + 1)
    sns.histplot(df_transactions[col], kde=True, bins=50)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Create box plots
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_features):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=df_transactions[col])
    plt.title(f'Box Plot of {col}')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %%
top_by_items = df_transactions.sort_values(by='TotalItemsInTransaction', ascending=False)
print(top_by_items.head(10)) # Show top 10
# Out:
#                TotalTransactionValue  TotalItemsInTransaction  \
# TransactionNo
# 581483                    1002718.10                    80995
# 541431                     840113.80                    74215
# 556917                     172833.48                    15049
# 563076                     159953.82                    14730
# 574941                     184880.85                    14149
# 576365                     184148.76                    13956
# 572035                     153882.12                    13392
# 567423                     161373.58                    12572
# 578841                      77622.60                    12540
# 552883                     130999.84                    12266
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# TransactionNo
# 581483                                   1                  12.380000
# 541431                                   1                  11.320000
# 556917                                 137                  12.010580
# 563076                                 119                  11.823613
# 574941                                 101                  14.780099
# 576365                                  99                  14.567172
# 572035                                 125                  12.631280
# 567423                                  12                  13.391667
# 578841                                   1                   6.190000
# 552883                                  92                  11.776304
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction  \
# TransactionNo
# 581483                             12.38                      12.38
# 541431                             11.32                      11.32
# 556917                              5.87                      25.57
# 563076                              5.87                      25.57
# 574941                              7.66                      26.74
# 576365                              7.66                      25.57
# 572035                              5.87                      25.57
# 567423                             11.36                      15.56
# 578841                              6.19                       6.19
# 552883                              5.87                      25.57
#
#               CustomerNo         Country TransactionDate
# TransactionNo
# 581483           16446.0  United Kingdom      2019-09-12
# 541431           12346.0  United Kingdom             NaT
# 556917           12415.0       Australia             NaT
# 563076           14646.0     Netherlands      2019-11-08
# 574941           15941.0  United Kingdom      2019-07-11
# 576365           14365.0  United Kingdom             NaT
# 572035           14646.0     Netherlands             NaT
# 567423           17450.0  United Kingdom             NaT
# 578841           13256.0  United Kingdom             NaT
# 552883           14646.0     Netherlands      2019-12-05

# %%
#To check if the same transactions are the cause of extreme negative values (large refund)
bottom_by_value = df_transactions.sort_values(by='TotalItemsInTransaction', ascending=True)
print(bottom_by_value.head(10))
# Out:
#                TotalTransactionValue  TotalItemsInTransaction  \
# TransactionNo
# 539645                         11.22                        1
# 539485                         30.70                        1
# 569516                         17.37                        1
# 553157                         18.71                        1
# 561516                         14.30                        1
# 562937                          5.97                        1
# 573933                         97.37                        1
# 543920                         18.96                        1
# 543922                         21.17                        1
# 578782                          6.19                        1
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# TransactionNo
# 539645                                   1                      11.22
# 539485                                   1                      30.70
# 569516                                   1                      17.37
# 553157                                   1                      18.71
# 561516                                   1                      14.30
# 562937                                   1                       5.97
# 573933                                   1                      97.37
# 543920                                   1                      18.96
# 543922                                   1                      21.17
# 578782                                   1                       6.19
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction  \
# TransactionNo
# 539645                             11.22                      11.22
# 539485                             30.70                      30.70
# 569516                             17.37                      17.37
# 553157                             18.71                      18.71
# 561516                             14.30                      14.30
# 562937                              5.97                       5.97
# 573933                             97.37                      97.37
# 543920                             18.96                      18.96
# 543922                             21.17                      21.17
# 578782                              6.19                       6.19
#
#               CustomerNo         Country TransactionDate
# TransactionNo
# 539645           17230.0  United Kingdom             NaT
# 539485           12485.0  United Kingdom             NaT
# 569516           15516.0  United Kingdom      2019-04-10
# 553157           13157.0  United Kingdom             NaT
# 561516           17516.0  United Kingdom             NaT
# 562937           16937.0  United Kingdom      2019-10-08
# 573933           17135.0  United Kingdom      2019-02-11
# 543920           14920.0  United Kingdom             NaT
# 543922           14922.0  United Kingdom             NaT
# 578782           15872.0  United Kingdom             NaT

# %%
#Specifically remove the 2 very large transactions
#The negative will be removed later
purchase_outlier_ids = ['581483', '541431']
df_transactions = df_transactions.drop(index=purchase_outlier_ids, errors='ignore')

# %%
df_transactions.describe()
# Out:
#        TotalTransactionValue  TotalItemsInTransaction  \
# count           19788.000000             19788.000000
# mean             3088.899456               274.726501
# min                 5.460000                 1.000000
# 25%               830.115000                71.000000
# 50%              1716.975000               153.000000
# 75%              3311.247500               298.000000
# max            184880.850000             15049.000000
# std              6412.263721               566.669697
#
#        UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# count                 19788.000000               19788.000000
# mean                     26.119264                  13.094378
# min                       1.000000                   5.460000
# 25%                       6.000000                  11.555121
# 50%                      15.000000                  12.693897
# 75%                      29.000000                  13.991778
# max                    1104.000000                 660.620000
# std                      46.913812                  13.837510
#
#        MinItemPriceInTransaction  MaxItemPriceInTransaction  \
# count               19788.000000               19788.000000
# mean                    9.751688                  20.700648
# min                     5.130000                   5.460000
# 25%                     6.130000                  14.090000
# 50%                    10.550000                  18.400000
# 75%                    11.120000                  23.060000
# max                   660.620000                 660.620000
# std                    13.111723                  31.786978
#
#                      TransactionDate
# count                           8485
# mean   2019-05-11 17:16:56.146140160
# min              2018-01-12 00:00:00
# 25%              2019-03-02 00:00:00
# 50%              2019-06-07 00:00:00
# 75%              2019-09-06 00:00:00
# max              2019-12-10 00:00:00
# std                              NaN

# %%
# Value counts for Country
country_counts = df_transactions['Country'].value_counts()
print("Value counts for Country:")
print(country_counts)
# Out:
# Value counts for Country:
# Country
# United Kingdom          17906
# Germany                   453
# France                    404
# EIRE                      277
# Belgium                    97
# Netherlands                94
# Spain                      78
# Australia                  62
# Switzerland                55
# Portugal                   52
# Finland                    42
# Sweden                     33
# Italy                      30
# Norway                     28
# Channel Islands            23
# Denmark                    21
# Japan                      20
# Unspecified                13
# Cyprus                     12
# Poland                     11
# Austria                    11
# Israel                     10
# Iceland                     8
# USA                         8
# Malta                       6
# Hong Kong                   6
# Canada                      5
# Lithuania                   4
# Singapore                   4
# European Community          3
# Bahrain                     2
# Czech Republic              2
# United Arab Emirates        2
# Greece                      2
# Saudi Arabia                1
# Lebanon                     1
# Brazil                      1
# RSA                         1
# Name: count, dtype: int64

# %%
# Percentage distribution
print("\nPercentage distribution for Country:")
print(df_transactions['Country'].value_counts(normalize=True) * 100)
# Out:
# Percentage distribution for Country:
# Country
# United Kingdom          90.489185
# Germany                  2.289266
# France                   2.041641
# EIRE                     1.399838
# Belgium                  0.490196
# Netherlands              0.475035
# Spain                    0.394178
# Australia                0.313321
# Switzerland              0.277946
# Portugal                 0.262786
# Finland                  0.212250
# Sweden                   0.166768
# Italy                    0.151607
# Norway                   0.141500
# Channel Islands          0.116232
# Denmark                  0.106125
# Japan                    0.101071
# Unspecified              0.065696
# Cyprus                   0.060643
# Poland                   0.055589
# Austria                  0.055589
# Israel                   0.050536
# Iceland                  0.040429
# USA                      0.040429
# Malta                    0.030321
# Hong Kong                0.030321
# Canada                   0.025268
# Lithuania                0.020214
# Singapore                0.020214
# European Community       0.015161
# Bahrain                  0.010107
# Czech Republic           0.010107
# United Arab Emirates     0.010107
# Greece                   0.010107
# Saudi Arabia             0.005054
# Lebanon                  0.005054
# Brazil                   0.005054
# RSA                      0.005054
# Name: proportion, dtype: float64

# %%
# Plotting the top N countries for better visualization
top_n = 10
plt.figure(figsize=(12, 6))
sns.barplot(x=country_counts.head(top_n).index, y=country_counts.head(top_n).values, palette="viridis")
plt.title(f'Top {top_n} Countries by Number of Transactions')
plt.xlabel('Country')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Number of unique countries
print(f"\nNumber of unique countries: {df_transactions['Country'].nunique()}")
# Out:
# /tmp/ipykernel_533/3979809828.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.head(top_n).index, y=country_counts.head(top_n).values, palette="viridis")
# Number of unique countries: 38

# %%
# Ensure TransactionDate is in datetime format
if not pd.api.types.is_datetime64_any_dtype(df_transactions['TransactionDate']):
    df_transactions['TransactionDate'] = pd.to_datetime(df_transactions['TransactionDate'])

# %%
# Extract temporal features

df_transactions['TransactionDayOfWeek'] = df_transactions['TransactionDate'].dt.dayofweek # Monday=0, Sunday=6
df_transactions['TransactionDayName'] = df_transactions['TransactionDate'].dt.day_name() # For easier interpretation
df_transactions['TransactionMonth'] = df_transactions['TransactionDate'].dt.month
df_transactions['TransactionYear'] = df_transactions['TransactionDate'].dt.year
df_transactions['TransactionIsWeekend'] = df_transactions['TransactionDayOfWeek'].isin([5, 6]).astype(int) # Saturday=5, Sunday=6

print("\nFirst 5 rows with new temporal features:")
print(df_transactions[['TransactionDate', 'TransactionDayOfWeek', 'TransactionDayName', 'TransactionMonth', 'TransactionIsWeekend']].head())
# Out:
# First 5 rows with new temporal features:
#               TransactionDate  TransactionDayOfWeek TransactionDayName  \
# TransactionNo
# 536365             2018-01-12                   4.0             Friday
# 536366             2018-01-12                   4.0             Friday
# 536367             2018-01-12                   4.0             Friday
# 536368             2018-01-12                   4.0             Friday
# 536369             2018-01-12                   4.0             Friday
#
#                TransactionMonth  TransactionIsWeekend
# TransactionNo
# 536365                      1.0                     0
# 536366                      1.0                     0
# 536367                      1.0                     0
# 536368                      1.0                     0
# 536369                      1.0                     0

# %%
# Explore distributions of time features
temporal_features_to_plot = ['TransactionDayName', 'TransactionMonth', 'TransactionIsWeekend']

plt.figure(figsize=(15, 10))
for i, col in enumerate(temporal_features_to_plot):
    plt.subplot(2, 2, i + 1)
    sns.countplot(data=df_transactions, x=col, palette="mako", order = df_transactions[col].value_counts().index if col not in ['TransactionDayName', 'TransactionMonth'] else sorted(df_transactions[col].unique()) if col == 'TransactionMonth' else ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Number of Transactions')
    if col == 'TransactionDayName':
        plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_533/3407706247.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_transactions, x=col, palette="mako", order = df_transactions[col].value_counts().index if col not in ['TransactionDayName', 'TransactionMonth'] else sorted(df_transactions[col].unique()) if col == 'TransactionMonth' else ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
# /tmp/ipykernel_533/3407706247.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_transactions, x=col, palette="mako", order = df_transactions[col].value_counts().index if col not in ['TransactionDayName', 'TransactionMonth'] else sorted(df_transactions[col].unique()) if col == 'TransactionMonth' else ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
# /tmp/ipykernel_533/3407706247.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_transactions, x=col, palette="mako", order = df_transactions[col].value_counts().index if col not in ['TransactionDayName', 'TransactionMonth'] else sorted(df_transactions[col].unique()) if col == 'TransactionMonth' else ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# %%
df_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19788 entries, 536365 to 581587
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   TotalTransactionValue        19788 non-null  float64
#  1   TotalItemsInTransaction      19788 non-null  int64
#  2   UniqueProductsInTransaction  19788 non-null  int64
#  3   AvgItemPriceInTransaction    19788 non-null  float64
#  4   MinItemPriceInTransaction    19788 non-null  float64
#  5   MaxItemPriceInTransaction    19788 non-null  float64
#  6   CustomerNo                   19788 non-null  object
#  7   Country                      19788 non-null  object
#  8   TransactionDate              8485 non-null   datetime64[ns]
#  9   TransactionDayOfWeek         8485 non-null   float64
#  10  TransactionDayName           8485 non-null   object
#  11  TransactionMonth             8485 non-null   float64
#  12  TransactionYear              8485 non-null   float64
#  13  TransactionIsWeekend         19788 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(3), object(3)
# memory usage: 2.8+ MB

# %% [markdown]
# Correlation analysis

# %%
# Select numerical features for correlation analysis
# create a list of features
features_for_correlation = [
    'TotalTransactionValue',
    'TotalItemsInTransaction',
    'UniqueProductsInTransaction',
    'AvgItemPriceInTransaction',
    'MinItemPriceInTransaction',
    'MaxItemPriceInTransaction',
    #might not be linear correlated
    'TransactionDayOfWeek',
    'TransactionMonth',
    'TransactionIsWeekend'

]

# %%
# Create a DataFrame with only the selected features for correlation
correlation_df = df_transactions[features_for_correlation].copy()

# Calculate the correlation matrix
correlation_matrix = correlation_df.corr()

# %%
# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Transaction Features')
plt.show()

# %% [markdown]
# Create final dataset

# %%
df_model = df_transactions.copy()

# %%
# Handle 'Country'
# Create 'Is_UK' feature and then drop 'Country' for clustering input
df_model['Is_UK'] = np.where(df_model['Country'] == 'United Kingdom', 1, 0)

# %%
# Select final numerical features for clustering
numerical_features_for_scaling = [
    'TotalTransactionValue',
    'TotalItemsInTransaction',
    'UniqueProductsInTransaction',
    'AvgItemPriceInTransaction',
    'MinItemPriceInTransaction',
    'MaxItemPriceInTransaction'
]

# %%
# Verify all selected numerical features exist
existing_numerical_features = [col for col in numerical_features_for_scaling if col in df_model.columns]
if len(existing_numerical_features) != len(numerical_features_for_scaling):
    print("Warning: Some numerical features listed for modeling are not in the DataFrame.")
    print(f"Using existing features: {existing_numerical_features}")
numerical_features_for_scaling = existing_numerical_features

# %%
# Select categorical features for one-hot encoding
categorical_features_to_encode = [ 'TransactionDayOfWeek' ]
# 'Is_UK' and 'TransactionIsWeekend' are already binary (0/1) and don't need OHE.

# Add already binary features to a list
binary_features = [ 'TransactionIsWeekend']

# %%
df_model_encoded = pd.get_dummies(df_model,
                                  columns=categorical_features_to_encode,
                                  prefix=categorical_features_to_encode,
                                  drop_first=False)


print(f"Shape after OHE: {df_model_encoded.shape}")
# Out:
# Shape after OHE: (19788, 21)

# %%
ohe_cols = [col for col in df_model_encoded.columns if any(cat_feat + "_" in col for cat_feat in categorical_features_to_encode)]

# %%
final_feature_columns_for_model = numerical_features_for_scaling +  ohe_cols # binary features excluded

# %%
# Create the final DataFrame for modeling input (X)
final_feature_columns_for_model = [col for col in final_feature_columns_for_model if col in df_model_encoded.columns]
X = df_model_encoded[final_feature_columns_for_model].copy()

# %%
X
# Out:
#                TotalTransactionValue  TotalItemsInTransaction  \
# TransactionNo
# 536365                        552.52                       40
# 536366                        145.80                       12
# 536367                       1136.34                       83
# 536368                        225.54                       15
# 536369                         49.05                        3
# ...                              ...                      ...
# 581583                        550.24                       76
# 581584                        868.80                      120
# 581585                       1863.17                      278
# 581586                        408.54                       66
# 581587                        649.95                      105
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# TransactionNo
# 536365                                   7                  14.255714
# 536366                                   2                  12.150000
# 536367                                  12                  15.224167
# 536368                                   4                  15.142500
# 536369                                   1                  16.350000
# ...                                    ...                        ...
# 581583                                   2                   7.240000
# 581584                                   2                   7.240000
# 581585                                  21                   6.749524
# 581586                                   4                   6.190000
# 581587                                  15                   6.190000
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction  \
# TransactionNo
# 536365                             12.86                      18.09
# 536366                             12.15                      12.15
# 536367                             11.94                      20.45
# 536368                             14.61                      15.32
# 536369                             16.35                      16.35
# ...                                  ...                        ...
# 581583                              7.24                       7.24
# 581584                              7.24                       7.24
# 581585                              6.19                       7.24
# 581586                              6.19                       6.19
# 581587                              6.19                       6.19
#
#                TransactionDayOfWeek_0.0  TransactionDayOfWeek_1.0  \
# TransactionNo
# 536365                            False                     False
# 536366                            False                     False
# 536367                            False                     False
# 536368                            False                     False
# 536369                            False                     False
# ...                                 ...                       ...
# 581583                            False                     False
# 581584                            False                     False
# 581585                            False                     False
# 581586                            False                     False
# 581587                            False                     False
#
#                TransactionDayOfWeek_2.0  TransactionDayOfWeek_3.0  \
# TransactionNo
# 536365                            False                     False
# 536366                            False                     False
# 536367                            False                     False
# 536368                            False                     False
# 536369                            False                     False
# ...                                 ...                       ...
# 581583                            False                      True
# 581584                            False                      True
# 581585                            False                      True
# 581586                            False                      True
# 581587                            False                      True
#
#                TransactionDayOfWeek_4.0  TransactionDayOfWeek_5.0  \
# TransactionNo
# 536365                             True                     False
# 536366                             True                     False
# 536367                             True                     False
# 536368                             True                     False
# 536369                             True                     False
# ...                                 ...                       ...
# 581583                            False                     False
# 581584                            False                     False
# 581585                            False                     False
# 581586                            False                     False
# 581587                            False                     False
#
#                TransactionDayOfWeek_6.0
# TransactionNo
# 536365                            False
# 536366                            False
# 536367                            False
# 536368                            False
# 536369                            False
# ...                                 ...
# 581583                            False
# 581584                            False
# 581585                            False
# 581586                            False
# 581587                            False
#
# [19788 rows x 13 columns]

# %%
from sklearn.preprocessing import StandardScaler
# Scale numerical features
scaler = StandardScaler()

# Fit the scaler on the numerical features and transform them
X[numerical_features_for_scaling] = scaler.fit_transform(X[numerical_features_for_scaling])

print("\nFirst 5 rows of X after scaling numerical features:")
print(X.head())
# Out:
# First 5 rows of X after scaling numerical features:
#                TotalTransactionValue  TotalItemsInTransaction  \
# TransactionNo
# 536365                     -0.395561                -0.414231
# 536366                     -0.458991                -0.463644
# 536367                     -0.304512                -0.338348
# 536368                     -0.446556                -0.458350
# 536369                     -0.474080                -0.479527
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# TransactionNo
# 536365                           -0.407550                   0.083929
# 536366                           -0.514132                  -0.068249
# 536367                           -0.300969                   0.153918
# 536368                           -0.471499                   0.148016
# 536369                           -0.535448                   0.235281
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction  \
# TransactionNo
# 536365                          0.237070                  -0.082132
# 536366                          0.182918                  -0.269005
# 536367                          0.166902                  -0.007885
# 536368                          0.370541                  -0.169276
# 536369                          0.503250                  -0.136872
#
#                TransactionDayOfWeek_0.0  TransactionDayOfWeek_1.0  \
# TransactionNo
# 536365                            False                     False
# 536366                            False                     False
# 536367                            False                     False
# 536368                            False                     False
# 536369                            False                     False
#
#                TransactionDayOfWeek_2.0  TransactionDayOfWeek_3.0  \
# TransactionNo
# 536365                            False                     False
# 536366                            False                     False
# 536367                            False                     False
# 536368                            False                     False
# 536369                            False                     False
#
#                TransactionDayOfWeek_4.0  TransactionDayOfWeek_5.0  \
# TransactionNo
# 536365                             True                     False
# 536366                             True                     False
# 536367                             True                     False
# 536368                             True                     False
# 536369                             True                     False
#
#                TransactionDayOfWeek_6.0
# TransactionNo
# 536365                            False
# 536366                            False
# 536367                            False
# 536368                            False
# 536369                            False

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19788 entries, 536365 to 581587
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   TotalTransactionValue        19788 non-null  float64
#  1   TotalItemsInTransaction      19788 non-null  float64
#  2   UniqueProductsInTransaction  19788 non-null  float64
#  3   AvgItemPriceInTransaction    19788 non-null  float64
#  4   MinItemPriceInTransaction    19788 non-null  float64
#  5   MaxItemPriceInTransaction    19788 non-null  float64
#  6   TransactionDayOfWeek_0.0     19788 non-null  bool
#  7   TransactionDayOfWeek_1.0     19788 non-null  bool
#  8   TransactionDayOfWeek_2.0     19788 non-null  bool
#  9   TransactionDayOfWeek_3.0     19788 non-null  bool
#  10  TransactionDayOfWeek_4.0     19788 non-null  bool
#  11  TransactionDayOfWeek_5.0     19788 non-null  bool
#  12  TransactionDayOfWeek_6.0     19788 non-null  bool
# dtypes: bool(7), float64(6)
# memory usage: 1.7+ MB

# %%
import time
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# Baseline models

# %%
# Determine a range of k values to try
k_values_to_try = range(2, 11) # from 2 to 10 clusters
silhouette_scores_kmeans = []
inertia_values = []
training_times_kmeans = []

# %%
# Determine a range of k values to try
k_values_to_try = range(2, 11)  # from 2 to 10 clusters
silhouette_scores_kmeans = []
inertia_values = []
training_times_kmeans = []
labels_kmeans_baseline = None  # Initialize the labels variable

for k in k_values_to_try:
    print(f"\nRunning K-Means with k={k}...")
    kmeans = KMeans(n_clusters=k, n_init='auto', random_state=42)
    start_time = time.time()
    kmeans.fit(X)
    end_time = time.time()
    training_time_seconds = end_time - start_time
    training_times_kmeans.append(training_time_seconds)
    
    # Get cluster labels
    if k == 3:  # Only store labels when k is 3
        labels_kmeans_baseline = kmeans.labels_

    # Calculate inertia (WCSS)
    inertia = kmeans.inertia_
    inertia_values.append(inertia)

    # Calculate Silhouette Score
    if k > 1 and k < X.shape[0]:
        score = silhouette_score(X, kmeans.labels_)
        silhouette_scores_kmeans.append(score)
        print(f"  Silhouette Score: {score:.4f}")
    else:
        silhouette_scores_kmeans.append(np.nan)

    print(f"  Inertia (WCSS): {inertia:.2f}")
    print(f"  Training Time: {training_time_seconds:.4f} seconds")
    print(f"  Number of iterations to converge: {kmeans.n_iter_}")
# Out:
# Running K-Means with k=2...
#   Silhouette Score: 0.8520
#   Inertia (WCSS): 104879.31
#   Training Time: 0.2028 seconds
#   Number of iterations to converge: 3
#
# Running K-Means with k=3...
#   Silhouette Score: 0.9144
#   Inertia (WCSS): 76876.05
#   Training Time: 0.1681 seconds
#   Number of iterations to converge: 2
#
# Running K-Means with k=4...
#   Silhouette Score: 0.8382
#   Inertia (WCSS): 53916.69
#   Training Time: 0.1908 seconds
#   Number of iterations to converge: 16
#
# Running K-Means with k=5...
#   Silhouette Score: 0.7088
#   Inertia (WCSS): 42584.24
#   Training Time: 0.2111 seconds
#   Number of iterations to converge: 26
#
# Running K-Means with k=6...
#   Silhouette Score: 0.5251
#   Inertia (WCSS): 35690.33
#   Training Time: 0.1900 seconds
#   Number of iterations to converge: 25
#
# Running K-Means with k=7...
#   Silhouette Score: 0.4271
#   Inertia (WCSS): 30640.68
#   Training Time: 0.2546 seconds
#   Number of iterations to converge: 30
#
# Running K-Means with k=8...
#   Silhouette Score: 0.4320
#   Inertia (WCSS): 27345.00
#   Training Time: 0.2356 seconds
#   Number of iterations to converge: 29
#
# Running K-Means with k=9...
#   Silhouette Score: 0.3384
#   Inertia (WCSS): 24547.43
#   Training Time: 0.2382 seconds
#   Number of iterations to converge: 28
#
# Running K-Means with k=10...
#   Silhouette Score: 0.2392
#   Inertia (WCSS): 23491.49
#   Training Time: 0.2454 seconds
#   Number of iterations to converge: 33

# %%
# Plotting the Elbow Method
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(k_values_to_try, inertia_values, marker='o')
plt.title('Elbow Method for optimal k (K-Means)')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia (WCSS)')
plt.xticks(list(k_values_to_try))
plt.grid(True)

# %%
# Plotting Silhouette Scores
plt.subplot(1, 2, 2)
plt.plot(k_values_to_try, silhouette_scores_kmeans, marker='o')
plt.title('Silhouette Scores for optimal k (K-Means)')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.xticks(list(k_values_to_try))
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
print("K-Means Training Times (seconds):")
for k_val, t_time in zip(k_values_to_try, training_times_kmeans):
    print(f"k={k_val}: {t_time:.4f} s")
# Out:
# K-Means Training Times (seconds):
# k=2: 0.2028 s
# k=3: 0.1681 s
# k=4: 0.1908 s
# k=5: 0.2111 s
# k=6: 0.1900 s
# k=7: 0.2546 s
# k=8: 0.2356 s
# k=9: 0.2382 s
# k=10: 0.2454 s

# %% [markdown]
# # PCA + Kmeans (baseline)

# %%
from sklearn.decomposition import PCA
def run_pca_kmeans(X, n_clusters):
    # Perform PCA to reduce dimensions to 5
    pca = PCA(n_components=5)
    X_pca = pca.fit_transform(X)

    # Start timing the KMeans fitting process
    start_time = time.time()

    # Apply KMeans clustering
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(X_pca)

    # Get cluster labels
    labels_kmeans = kmeans.labels_

    # Calculate silhouette score
    silhouette = silhouette_score(X_pca, labels_kmeans)

    # Compute training time
    training_time = time.time() - start_time

    return silhouette, training_time, X_pca, labels_kmeans

# Running PCA + KMeans Baseline
n_clusters = 3  # Specify the number of clusters for KMeans
silhouette_pca_kmeans, time_pca_kmeans, X_pca, labels_kmeans = run_pca_kmeans(X, n_clusters)

# Print results
print(f"PCA + KMeans Baseline - Silhouette Score: {silhouette_pca_kmeans:.4f}, Training Time: {time_pca_kmeans:.4f} seconds")
# Out:
# PCA + KMeans Baseline - Silhouette Score: 0.8652, Training Time: 4.5684 seconds

# %%
# Plotting the PCA results with KMeans clusters
plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels_kmeans, cmap='viridis', marker='o', edgecolor='k')
plt.title('PCA + KMeans Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster Label')
plt.grid(True)
plt.show()

# %% [markdown]
# # Autoencoder + Kmeans (baseline)

# %%
#Imports
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split # for validations

# %%
n_inputs = X.values.shape[1]
print(f"Number of input features for Autoencoder: {n_inputs}")
# Out:
# Number of input features for Autoencoder: 13

# %%
def create_autoencoder(input_shape):
    model = keras.Sequential([
        layers.Input(shape=input_shape),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(8, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(input_shape[0], activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
def run_autoencoder_kmeans(X, n_clusters):
    autoencoder = create_autoencoder(X.shape[1:])

    # Fit the Autoencoder
    start_time = time.time()
    history = autoencoder.fit(X, X, epochs=50, batch_size=32, verbose=0)
    training_time = time.time() - start_time

    # Get the reconstruction loss
    reconstruction_loss = history.history['loss'][-1]  # Get the last epoch loss

    # Encode the data
    X_encoded = autoencoder.predict(X)

    # Fit KMeans
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(X_encoded)
    labels_autoencoder_kmeans = kmeans.labels_

    # Calculate silhouette score
    silhouette = silhouette_score(X_encoded, labels_autoencoder_kmeans)

    return reconstruction_loss, silhouette, training_time, labels_autoencoder_kmeans

# %%
# Running Autoencoder + KMeans Baseline
reconstruction_loss, silhouette_autoencoder_kmeans, time_autoencoder_kmeans, labels_autoencoder_kmeans = run_autoencoder_kmeans(X, n_clusters=3)
# Out:
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 1s 796us/step

# %%
# Model Evaluation
print(f"Autoencoder + KMeans Baseline Evaluation:")
print(f" - Reconstruction Loss: {reconstruction_loss:.4f}")
print(f" - Silhouette Score: {silhouette_autoencoder_kmeans:.4f}")
print(f" - Training Time: {time_autoencoder_kmeans:.4f} seconds")
# Out:
# Autoencoder + KMeans Baseline Evaluation:
#  - Reconstruction Loss: 0.3748
#  - Silhouette Score: 0.3523
#  - Training Time: 55.3167 seconds

# %% [markdown]
# #Finetuned model compositions

# %% [markdown]
# ## PCA + Kmeans (Finetuned)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster    import KMeans
from sklearn.metrics    import silhouette_score

# %%
#Grid-search PCA + K-Means
results = []
for n_comp in range(2, min(X.shape[1], 15)+1):
    pca   = PCA(n_components=n_comp, random_state=42)
    X_pca = pca.fit_transform(X)
    for K in range(2, 11):
        km     = KMeans(n_clusters=K, random_state=42)
        labels = km.fit_predict(X_pca)
        score  = silhouette_score(X_pca, labels)
        results.append((n_comp, K, score))

grid = pd.DataFrame(results, columns=['n_components','K','silhouette'])
best = grid.loc[grid['silhouette'].idxmax()]
n_best, K_best, best_score = best

print(f"Best: {int(n_best)} PCA comps + K={int(K_best)} → silhouette={best_score:.4f}")
# Out:
# Best: 7 PCA comps + K=3 → silhouette=0.9211

# %%
start_time = time.time()

pca_best = PCA(n_components=int(n_best), random_state=42)
X_pca_best = pca_best.fit_transform(X)

km_best = KMeans(n_clusters=int(K_best), random_state=42)
labels_best = km_best.fit_predict(X_pca_best)   

elapsed = time.time() - start_time

print(f"Best: {int(n_best)} PCA comps + K={int(K_best)} → silhouette={best_score:.4f} → training time={elapsed:.4f}s")
# Out:
# Best: 7 PCA comps + K=3 → silhouette=0.9211 → training time=0.1664s

# %%
pca_final    = PCA(n_components=int(n_best), random_state=42)
X_pca_final  = pca_final.fit_transform(X)
km_final      = KMeans(n_clusters=int(K_best), random_state=42)
cluster_labels_pca_ft = km_final.fit_predict(X_pca_final)

# %% [markdown]
# ## Autoencoder + Kmeans (Finetuned)

# %%
#Hyperparameters for shallow autoencoder
#Convert from dataframe to numpy array
X_np = X
n_inputs = X_np.shape[1]
coding_size = 6

lr = 0.0005
act_func = "selu"
init= "lecun_normal"
opt = "nadam"
dense1 = 64
btch_size = 64
epochs_num = 50

# %%
#encoder
encoder = keras.models.Sequential([
    keras.layers.InputLayer(input_shape=[n_inputs]),
    keras.layers.Dense(dense1, activation=act_func, kernel_initializer=init),
    keras.layers.Dense(coding_size, activation=None) #bottleneck layer
], name="encoder")

#decoder
decoder = keras.models.Sequential([
    keras.layers.InputLayer(input_shape=[coding_size]),
    keras.layers.Dense(dense1, activation=act_func, kernel_initializer=init),
    keras.layers.Dense(n_inputs, activation=None)
], name="decoder")

#autoencoder
shallow_autoencoder = keras.models.Sequential([encoder, decoder], name="Shallow Autoencoder")

shallow_autoencoder.summary()
# Out:
# /opt/conda/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "Shallow Autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder (Sequential)            │ (None, 6)              │         1,286 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Sequential)            │ (None, 13)             │         1,293 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,579 (10.07 KB)
#  Trainable params: 2,579 (10.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the autoencoder
from tensorflow.keras.optimizers import Nadam
# Create the optimizer
opt = Nadam(learning_rate=lr)
# Compile only with optimizer and loss
shallow_autoencoder.compile(optimizer=opt, loss='mse')

# %%
#allocate 10% for validation set to check for overfitting when reconstructing data
X_train_ae, X_val_ae = train_test_split(X_np, test_size=0.1, random_state=42)

print(f"Training autoencoder on {X_train_ae.shape[0]} samples, validating on {X_val_ae.shape[0]} samples.")

start_time_ae = time.time()
history_ae =shallow_autoencoder.fit(X_train_ae, X_train_ae,
                           epochs=epochs_num,
                           batch_size=btch_size,
                           validation_data=(X_val_ae, X_val_ae),
                           callbacks=[
                               keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
                           ])
end_time_ae = time.time()
training_time_ae = end_time_ae - start_time_ae
print(f"Shallow Autoencoder training time: {training_time_ae:.2f} seconds")
# Out:
# Training autoencoder on 17809 samples, validating on 1979 samples.
# Epoch 1/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8116 - val_loss: 0.2383
# Epoch 2/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1342 - val_loss: 0.0679
# Epoch 3/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0562 - val_loss: 0.0363
# Epoch 4/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0376 - val_loss: 0.0290
# Epoch 5/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0321 - val_loss: 0.0259
# Epoch 6/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0268 - val_loss: 0.0238
# Epoch 7/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0248 - val_loss: 0.0224
# Epoch 8/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0239 - val_loss: 0.0200
# Epoch 9/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0221 - val_loss: 0.0206
# Epoch 10/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0207 - val_loss: 0.0185
# Epoch 11/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0185 - val_loss: 0.0158
# Epoch 12/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0156 - val_loss: 0.0145
# Epoch 13/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0159 - val_loss: 0.0136
# Epoch 14/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0139 - val_loss: 0.0211
# Epoch 15/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0211 - val_loss: 0.0106
# Epoch 16/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0110 - val_loss: 0.0099
# Epoch 17/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0097 - val_loss: 0.0090
# Epoch 18/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0097
# Epoch 19/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0102
# Epoch 20/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0087 - val_loss: 0.0082
# Epoch 21/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0086 - val_loss: 0.0084
# Epoch 22/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0075 - val_loss: 0.0070
# Epoch 23/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0072 - val_loss: 0.0076
# Epoch 24/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0074 - val_loss: 0.0062
# Epoch 25/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0065 - val_loss: 0.0126
# Epoch 26/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0091 - val_loss: 0.0091
# Epoch 27/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0076 - val_loss: 0.0057
# Epoch 28/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 29/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0068 - val_loss: 0.0078
# Epoch 30/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 31/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0054 - val_loss: 0.0089
# Epoch 32/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 33/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 34/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0048 - val_loss: 0.0060
# Epoch 35/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0046 - val_loss: 0.0106
# Epoch 36/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0067 - val_loss: 0.0086
# Epoch 37/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0075 - val_loss: 0.0072
# Epoch 38/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0048 - val_loss: 0.0062
# Epoch 39/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 40/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0041 - val_loss: 0.0050
# Epoch 41/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0043 - val_loss: 0.0061
# Epoch 42/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 43/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0041 - val_loss: 0.0048
# Epoch 44/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 45/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0051 - val_loss: 0.0039
# Epoch 46/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 47/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 48/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 49/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 50/50
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0042 - val_loss: 0.0036
# Shallow Autoencoder training time: 36.34 seconds

# %%
# Plot learning curves for the autoencoder
pd.DataFrame(history_ae.history).plot(figsize=(8, 5))
plt.grid(True)
plt.title("Autoencoder Training Curves")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()

# %%
#transform in to new low dimension dataset
X_encoded = encoder.predict(X_np)
print(X_np.shape) # training data
print(X_encoded.shape) # encoded data
# Out:
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# (19788, 13)
# (19788, 6)

# %%
# Use encoded data in Kmeans
k_values_to_try_ae = range(2, 15)
silhouette_scores_kmeans_ae = []
inertia_values_ae = []
training_times_kmeans_ae = []

for k_ae in k_values_to_try_ae:
    print(f"\nRunning K-Means on encoded data with k={k_ae}...")
    kmeans_ae = KMeans(n_clusters=k_ae, init='k-means++', n_init='auto', random_state=42)

    start_time_km_ae = time.time()
    labels_kmeans_ae = kmeans_ae.fit_predict(X_encoded)
    end_time_km_ae = time.time()

    training_time_seconds_km_ae = end_time_km_ae - start_time_km_ae
    training_times_kmeans_ae.append(training_time_seconds_km_ae)

    inertia_ae = kmeans_ae.inertia_
    inertia_values_ae.append(inertia_ae)

    if k_ae > 1 and k_ae < X_encoded.shape[0]:
        score_ae = silhouette_score(X_encoded, labels_kmeans_ae)
        silhouette_scores_kmeans_ae.append(score_ae)
        print(f"  Silhouette Score: {score_ae:.4f}")
    else:
        silhouette_scores_kmeans_ae.append(np.nan)

    print(f"  Inertia (WCSS): {inertia_ae:.2f}")
    print(f"  K-Means training time: {training_time_seconds_km_ae:.4f} seconds")
    print(f"  Number of iterations to converge: {kmeans_ae.n_iter_}")
# Out:
# Running K-Means on encoded data with k=2...
#   Silhouette Score: 0.5773
#   Inertia (WCSS): 77253.12
#   K-Means training time: 0.0316 seconds
#   Number of iterations to converge: 6
#
# Running K-Means on encoded data with k=3...
#   Silhouette Score: 0.6174
#   Inertia (WCSS): 67074.96
#   K-Means training time: 0.1653 seconds
#   Number of iterations to converge: 8
#
# Running K-Means on encoded data with k=4...
#   Silhouette Score: 0.6119
#   Inertia (WCSS): 49684.46
#   K-Means training time: 0.0266 seconds
#   Number of iterations to converge: 5
#
# Running K-Means on encoded data with k=5...
#   Silhouette Score: 0.5922
#   Inertia (WCSS): 41961.05
#   K-Means training time: 0.0293 seconds
#   Number of iterations to converge: 5
#
# Running K-Means on encoded data with k=6...
#   Silhouette Score: 0.5951
#   Inertia (WCSS): 29958.35
#   K-Means training time: 0.0437 seconds
#   Number of iterations to converge: 5
#
# Running K-Means on encoded data with k=7...
#   Silhouette Score: 0.5958
#   Inertia (WCSS): 27514.35
#   K-Means training time: 0.0345 seconds
#   Number of iterations to converge: 5
#
# Running K-Means on encoded data with k=8...
#   Silhouette Score: 0.6023
#   Inertia (WCSS): 22546.85
#   K-Means training time: 0.0703 seconds
#   Number of iterations to converge: 6
#
# Running K-Means on encoded data with k=9...
#   Silhouette Score: 0.5983
#   Inertia (WCSS): 18213.04
#   K-Means training time: 0.0407 seconds
#   Number of iterations to converge: 7
#
# Running K-Means on encoded data with k=10...
#   Silhouette Score: 0.5927
#   Inertia (WCSS): 15985.01
#   K-Means training time: 0.0567 seconds
#   Number of iterations to converge: 15
#
# Running K-Means on encoded data with k=11...
#   Silhouette Score: 0.5931
#   Inertia (WCSS): 14340.96
#   K-Means training time: 0.0570 seconds
#   Number of iterations to converge: 15
#
# Running K-Means on encoded data with k=12...
#   Silhouette Score: 0.5968
#   Inertia (WCSS): 12871.63
#   K-Means training time: 0.0687 seconds
#   Number of iterations to converge: 21
#
# Running K-Means on encoded data with k=13...
#   Silhouette Score: 0.6130
#   Inertia (WCSS): 10477.20
#   K-Means training time: 0.0536 seconds
#   Number of iterations to converge: 12
#
# Running K-Means on encoded data with k=14...
#   Silhouette Score: 0.6581
#   Inertia (WCSS): 8311.89
#   K-Means training time: 0.0853 seconds
#   Number of iterations to converge: 13

# %%
best_k_ae = k_values_to_try_ae[np.argmax(silhouette_scores_kmeans_ae)]
best_silhouette_ae = np.nanmax(silhouette_scores_kmeans_ae)

# %%
final_kmeans_ae = KMeans(n_clusters=best_k_ae, init='k-means++', n_init='auto', random_state=42)
labels_ae_shallow = final_kmeans_ae.fit_predict(X_encoded)

# %%
#TSNE to visualize clusters
from sklearn.manifold import TSNE
tsne_ae = TSNE(n_components=2, random_state=42, perplexity=30, max_iter=1000) #

X_tsne_ae = tsne_ae.fit_transform(X_encoded)

tsne_ae_df = pd.DataFrame(data=X_tsne_ae, columns=['TSNE1_AE', 'TSNE2_AE'])
tsne_ae_df['KMeans_AE_Labels'] = labels_ae_shallow

plt.figure(figsize=(8, 6))
sns.scatterplot(
    x="TSNE1_AE", y="TSNE2_AE",
    hue="KMeans_AE_Labels",
   palette=sns.color_palette("hsv", len(set(labels_ae_shallow))),
  data=tsne_ae_df,
  legend="full",
  alpha=0.7
)
plt.title(f't-SNE of AE Codings (colored by K-Means k={best_k_ae})')
plt.xlabel('TSNE AE Component 1')
plt.ylabel('TSNE AE Component 2')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Automated finetuning with KerasTuner*

# %%
import keras_tuner as kt

def build_ae_hypermodel(hp):
  n_inputs = 13 #diemensions of input data
  coding_size = hp.Int('coding_size', min_value=4, max_value=10, step=2)
  units_l1 = hp.Int('units_l1', min_value=32, max_value=128, step=32)
  units_l2 = hp.Int('units_l2', min_value=16, max_value=64, step=16)
  activation = hp.Choice('activation', ['selu', 'relu'])
  lr = hp.Choice('learning_rate', [0.001, 0.0005])

  encoder = keras.models.Sequential([
      keras.layers.InputLayer(shape=[n_inputs]),
      keras.layers.Dense(units_l1, activation=activation, kernel_initializer='lecun_normal' if activation=='selu' else 'he_normal'),
      keras.layers.Dense(units_l2, activation=activation, kernel_initializer='lecun_normal' if activation=='selu' else 'he_normal'), # If deeper
      keras.layers.Dense(coding_size, activation=None)
   ])

  decoder = keras.models.Sequential([
      keras.layers.InputLayer(shape=[coding_size]),
      keras.layers.Dense(units_l2, activation=activation, kernel_initializer='lecun_normal' if activation=='selu' else 'he_normal'), # If deeper
      keras.layers.Dense(units_l1, activation=activation, kernel_initializer='lecun_normal' if activation=='selu' else 'he_normal'),
      keras.layers.Dense(n_inputs, activation=None)
  ])
  autoencoder = keras.models.Sequential([encoder, decoder])
  autoencoder.compile(loss="mse", optimizer=keras.optimizers.Nadam(learning_rate=lr))
  return autoencoder

tuner = kt.RandomSearch(
    build_ae_hypermodel,
    objective='val_loss',
    max_trials=10,
    executions_per_trial=1,
    directory='my_ae_tuning',
    project_name='transaction_ae'
)
tuner.search(X_train_ae, X_train_ae, epochs=50, validation_data=(X_val_ae, X_val_ae),
              callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)])

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
best_ae_model = tuner.get_best_models(num_models=1)[0]
print(f"Best AE HPs for reconstruction: {best_hps.values}")
# Out:
# Trial 10 Complete [00h 01m 10s]
# val_loss: 0.0014843677636235952
#
# Best val_loss So Far: 0.0011712285922840238
# Total elapsed time: 00h 10m 21s
# Best AE HPs for reconstruction: {'coding_size': 8, 'units_l1': 64, 'units_l2': 64, 'activation': 'selu', 'learning_rate': 0.0005}
# /opt/conda/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'nadam', because it has 2 variables whereas the saved optimizer has 27 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ## Deep Autoencoder + Kmeans

# %%
X_np = X # Reset numpy array

#Hyperparameters
n_inputs = X_np.shape[1]
coding_size = 6 # coding for bottleneck layer

lr = 0.0005
act_func = "relu"
init= "he_normal"
reg = keras.regularizers.l1(1e-5)


dense1 = 128
dense2 = 64
dense3 = 32
btch_size = 64
epochs_num = 100

# %%
#encoder
encoder = keras.models.Sequential([
    keras.layers.InputLayer(input_shape=[n_inputs]),
    keras.layers.Dense(dense1, activation=act_func, kernel_initializer=init, kernel_regularizer=reg),
    keras.layers.Dense(dense2, activation=act_func, kernel_initializer=init,kernel_regularizer=reg ),
    keras.layers.Dense(dense3, activation=act_func, kernel_initializer=init, kernel_regularizer=reg),
    keras.layers.Dense(coding_size, activation=None) #bottleneck layer
], name="encoder")

#decoder
decoder = keras.models.Sequential([
    keras.layers.InputLayer(input_shape=[coding_size]),
    keras.layers.Dense(dense3, activation=act_func, kernel_initializer=init, kernel_regularizer=reg),
    keras.layers.Dense(dense2, activation=act_func, kernel_initializer=init, kernel_regularizer=reg ),
    keras.layers.Dense(dense1, activation=act_func, kernel_initializer=init, kernel_regularizer=reg),
    keras.layers.Dense(n_inputs, activation=None)
], name="decoder")

#autoencoder
deep_autoencoder = keras.models.Sequential([encoder, decoder], name="Deep Autoencoder")

deep_autoencoder.summary()
# Out:
# /opt/conda/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "Deep Autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder (Sequential)            │ (None, 6)              │        12,326 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Sequential)            │ (None, 13)             │        12,333 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,659 (96.32 KB)
#  Trainable params: 24,659 (96.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile
from tensorflow.keras.optimizers import Nadam
# Create the optimizer
opt = Nadam(learning_rate=lr)
# Compile only with optimizer and loss
deep_autoencoder.compile(optimizer=opt, loss='mse')

# %%
#allocate 10% for validation set to check for overfitting when reconstructing data

X_train_ae, X_val_ae = train_test_split(X_np, test_size=0.1, random_state=42)

print(f"Training autoencoder on {X_train_ae.shape[0]} samples, validating on {X_val_ae.shape[0]} samples.")

start_time_ae = time.time()
history_ae =deep_autoencoder.fit(X_train_ae, X_train_ae,
                           epochs=epochs_num,
                           batch_size=btch_size,
                           validation_data=(X_val_ae, X_val_ae),
                           callbacks=[
                               keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
                           ])
end_time_ae = time.time()
training_time_ae = end_time_ae - start_time_ae
print(f"Deep Autoencoder training time: {training_time_ae:.2f} seconds")
# Out:
# Training autoencoder on 17809 samples, validating on 1979 samples.
# Epoch 1/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.4734 - val_loss: 0.0696
# Epoch 2/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0792 - val_loss: 0.0524
# Epoch 3/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0522 - val_loss: 0.0844
# Epoch 4/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0879 - val_loss: 0.0559
# Epoch 5/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0481 - val_loss: 0.1063
# Epoch 6/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0962 - val_loss: 0.0382
# Epoch 7/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0406 - val_loss: 0.0663
# Epoch 8/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0500 - val_loss: 0.0436
# Epoch 9/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0401 - val_loss: 0.0496
# Epoch 10/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0468 - val_loss: 0.0403
# Epoch 11/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0359 - val_loss: 0.0366
# Epoch 12/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0358 - val_loss: 0.0339
# Epoch 13/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0328 - val_loss: 0.0335
# Epoch 14/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - val_loss: 0.0330
# Epoch 15/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0326 - val_loss: 0.0620
# Epoch 16/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0493 - val_loss: 0.0601
# Epoch 17/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0657 - val_loss: 0.0400
# Epoch 18/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0342 - val_loss: 0.0381
# Epoch 19/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0390 - val_loss: 0.0349
# Epoch 20/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0401 - val_loss: 0.0346
# Epoch 21/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0311 - val_loss: 0.0311
# Epoch 22/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0305 - val_loss: 0.0539
# Epoch 23/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0421 - val_loss: 0.0311
# Epoch 24/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0301 - val_loss: 0.0322
# Epoch 25/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0389 - val_loss: 0.0328
# Epoch 26/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0297 - val_loss: 0.0706
# Epoch 27/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0359 - val_loss: 0.0376
# Epoch 28/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0308 - val_loss: 0.0372
# Epoch 29/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0344 - val_loss: 0.0290
# Epoch 30/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0271 - val_loss: 0.0284
# Epoch 31/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0274 - val_loss: 0.0267
# Epoch 32/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0260 - val_loss: 0.0262
# Epoch 33/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0268 - val_loss: 0.0442
# Epoch 34/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0362 - val_loss: 0.0285
# Epoch 35/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0314 - val_loss: 0.0282
# Epoch 36/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0256 - val_loss: 0.0271
# Epoch 37/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0256 - val_loss: 0.0261
# Epoch 38/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0244 - val_loss: 0.0243
# Epoch 39/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0249 - val_loss: 0.0370
# Epoch 40/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0257 - val_loss: 0.0474
# Epoch 41/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0326 - val_loss: 0.0278
# Epoch 42/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0284 - val_loss: 0.0235
# Epoch 43/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0225 - val_loss: 0.0222
# Epoch 44/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0221 - val_loss: 0.0230
# Epoch 45/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0219 - val_loss: 0.0231
# Epoch 46/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0223 - val_loss: 0.0244
# Epoch 47/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0256 - val_loss: 0.0220
# Epoch 48/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0250 - val_loss: 0.0226
# Epoch 49/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0244 - val_loss: 0.0900
# Epoch 50/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0445 - val_loss: 0.0225
# Epoch 51/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0204 - val_loss: 0.0207
# Epoch 52/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0204 - val_loss: 0.0196
# Epoch 53/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0197 - val_loss: 0.0197
# Epoch 54/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0207 - val_loss: 0.0417
# Epoch 55/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0335 - val_loss: 0.0199
# Epoch 56/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0200 - val_loss: 0.0187
# Epoch 57/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0184 - val_loss: 0.0183
# Epoch 58/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0182 - val_loss: 0.0190
# Epoch 59/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0178 - val_loss: 0.0184
# Epoch 60/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0257 - val_loss: 0.0664
# Epoch 61/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0298 - val_loss: 0.0188
# Epoch 62/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0184 - val_loss: 0.0185
# Epoch 63/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0172 - val_loss: 0.0177
# Epoch 64/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0179 - val_loss: 0.0169
# Epoch 65/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0172 - val_loss: 0.0176
# Epoch 66/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0173 - val_loss: 0.0174
# Epoch 67/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0167 - val_loss: 0.0367
# Epoch 68/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0361 - val_loss: 0.0165
# Epoch 69/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0169 - val_loss: 0.0171
# Epoch 70/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0159 - val_loss: 0.0151
# Epoch 71/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0152 - val_loss: 0.0229
# Epoch 72/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0186 - val_loss: 0.0176
# Epoch 73/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0169 - val_loss: 0.0222
# Epoch 74/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0171 - val_loss: 0.0170
# Epoch 75/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0160 - val_loss: 0.0142
# Epoch 76/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0138 - val_loss: 0.0145
# Epoch 77/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0141 - val_loss: 0.0141
# Epoch 78/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0141 - val_loss: 0.0188
# Epoch 79/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0180 - val_loss: 0.0170
# Epoch 80/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0136 - val_loss: 0.0152
# Epoch 81/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0238 - val_loss: 0.0154
# Epoch 82/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0138 - val_loss: 0.0137
# Epoch 83/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0130 - val_loss: 0.0132
# Epoch 84/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0142 - val_loss: 0.0208
# Epoch 85/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0151 - val_loss: 0.0223
# Epoch 86/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0179 - val_loss: 0.0204
# Epoch 87/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0158 - val_loss: 0.0139
# Epoch 88/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0134 - val_loss: 0.0127
# Epoch 89/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0125 - val_loss: 0.0123
# Epoch 90/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0121 - val_loss: 0.0125
# Epoch 91/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0120 - val_loss: 0.0119
# Epoch 92/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0129 - val_loss: 0.0127
# Epoch 93/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0139 - val_loss: 0.0150
# Epoch 94/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0172 - val_loss: 0.0118
# Epoch 95/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0120 - val_loss: 0.0117
# Epoch 96/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0117 - val_loss: 0.0120
# Epoch 97/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0114 - val_loss: 0.0116
# Epoch 98/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0111 - val_loss: 0.0140
# Epoch 99/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0125 - val_loss: 0.0113
# Epoch 100/100
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0130 - val_loss: 0.0135
# Deep Autoencoder training time: 101.85 seconds

# %%
# Plot learning curves for the deep autoencoder
pd.DataFrame(history_ae.history).plot(figsize=(8, 5))
plt.grid(True)
plt.title("Autoencoder Training Curves")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()

# %%
#transform in to new low dimension dataset
X_encoded = encoder.predict(X_np)
print(X_np.shape) # training data
print(X_encoded.shape) # encoded data
# Out:
# 619/619 ━━━━━━━━━━━━━━━━━━━━ 1s 1000us/step
# (19788, 13)
# (19788, 6)

# %%
# Use encoded data in Kmeans
k_values_to_try_ae = range(2, 15)
silhouette_scores_kmeans_ae = []
inertia_values_ae = []
training_times_kmeans_ae = []

for k_ae in k_values_to_try_ae:
    print(f"\nRunning K-Means on encoded data with k={k_ae}...")
    kmeans_ae = KMeans(n_clusters=k_ae, init='k-means++', n_init='auto', random_state=42)

    start_time_km_ae = time.time()
    labels_kmeans_ae = kmeans_ae.fit_predict(X_encoded)
    end_time_km_ae = time.time()

    training_time_seconds_km_ae = end_time_km_ae - start_time_km_ae
    training_times_kmeans_ae.append(training_time_seconds_km_ae)

    inertia_ae = kmeans_ae.inertia_
    inertia_values_ae.append(inertia_ae)

    if k_ae > 1 and k_ae < X_encoded.shape[0]:
        score_ae = silhouette_score(X_encoded, labels_kmeans_ae)
        silhouette_scores_kmeans_ae.append(score_ae)
        print(f"  Silhouette Score: {score_ae:.4f}")
    else:
        silhouette_scores_kmeans_ae.append(np.nan)

    print(f"  Inertia (WCSS): {inertia_ae:.2f}")
    print(f"  K-Means Training Time: {training_time_seconds_km_ae:.4f} seconds")
    print(f"  Number of iterations to converge: {kmeans_ae.n_iter_}")
# Out:
# Running K-Means on encoded data with k=2...
#   Silhouette Score: 0.4885
#   Inertia (WCSS): 47851.93
#   K-Means Training Time: 0.2144 seconds
#   Number of iterations to converge: 6
#
# Running K-Means on encoded data with k=3...
#   Silhouette Score: 0.8968
#   Inertia (WCSS): 35091.38
#   K-Means Training Time: 0.0657 seconds
#   Number of iterations to converge: 2
#
# Running K-Means on encoded data with k=4...
#   Silhouette Score: 0.3579
#   Inertia (WCSS): 29268.93
#   K-Means Training Time: 0.0422 seconds
#   Number of iterations to converge: 13
#
# Running K-Means on encoded data with k=5...
#   Silhouette Score: 0.4450
#   Inertia (WCSS): 22207.71
#   K-Means Training Time: 0.0456 seconds
#   Number of iterations to converge: 7
#
# Running K-Means on encoded data with k=6...
#   Silhouette Score: 0.4565
#   Inertia (WCSS): 18036.43
#   K-Means Training Time: 0.0432 seconds
#   Number of iterations to converge: 8
#
# Running K-Means on encoded data with k=7...
#   Silhouette Score: 0.5346
#   Inertia (WCSS): 14297.52
#   K-Means Training Time: 0.0393 seconds
#   Number of iterations to converge: 8
#
# Running K-Means on encoded data with k=8...
#   Silhouette Score: 0.5333
#   Inertia (WCSS): 13896.08
#   K-Means Training Time: 0.0438 seconds
#   Number of iterations to converge: 10
#
# Running K-Means on encoded data with k=9...
#   Silhouette Score: 0.5331
#   Inertia (WCSS): 12718.30
#   K-Means Training Time: 0.0544 seconds
#   Number of iterations to converge: 10
#
# Running K-Means on encoded data with k=10...
#   Silhouette Score: 0.5448
#   Inertia (WCSS): 11143.55
#   K-Means Training Time: 0.0713 seconds
#   Number of iterations to converge: 13
#
# Running K-Means on encoded data with k=11...
#   Silhouette Score: 0.5489
#   Inertia (WCSS): 10170.30
#   K-Means Training Time: 0.0510 seconds
#   Number of iterations to converge: 9
#
# Running K-Means on encoded data with k=12...
#   Silhouette Score: 0.5736
#   Inertia (WCSS): 8664.54
#   K-Means Training Time: 0.0494 seconds
#   Number of iterations to converge: 11
#
# Running K-Means on encoded data with k=13...
#   Silhouette Score: 0.4383
#   Inertia (WCSS): 8752.29
#   K-Means Training Time: 0.0507 seconds
#   Number of iterations to converge: 10
#
# Running K-Means on encoded data with k=14...
#   Silhouette Score: 0.4854
#   Inertia (WCSS): 7332.47
#   K-Means Training Time: 0.0619 seconds
#   Number of iterations to converge: 13

# %%
best_k_ae = k_values_to_try_ae[np.argmax(silhouette_scores_kmeans_ae)]
best_silhouette_ae = np.nanmax(silhouette_scores_kmeans_ae)

# %%
final_kmeans_ae = KMeans(n_clusters=best_k_ae, init='k-means++', n_init='auto', random_state=42)
labels_ae_deep = final_kmeans_ae.fit_predict(X_encoded)

# %% [markdown]
# # **Analyzing cluster results**

# %%
# Cluster analysis function

def cluster_analysis (
    df_cleaned: pd.DataFrame,
    cluster_input_df: pd.DataFrame,
    cluster_labels: np.ndarray,
    num_cols: list,
    cat_cols: list,
    model_name: str
):
  print(f"Cluster analysis for {model_name}")


  df_segment = df_cleaned.loc[cluster_input_df.index].copy()
  df_segment['Cluster_Label'] = cluster_labels

  # Cluster sizes
  cluster_sizes = df_segment['Cluster_Label'].value_counts().sort_index()
  print("Cluster Sizes:")
  print(cluster_sizes)

  # segments numerical features
  valid_num_features = [col for col in num_cols if col in df_segment.columns]

  cluster_num_segment = df_segment.groupby('Cluster_Label')[valid_num_features].mean()
  print("Cluster segment:")
  print(cluster_num_segment)


# encoded/categorical feature (only weekdays)
  valid_cat_features = [col for col in cat_cols if col in df_segment.columns]

  segment_cat_dist = df_segment.groupby('Cluster_Label')[col].value_counts(normalize=True).mul(100).round(1)
  segment_cat_plot = segment_cat_dist.unstack(fill_value=0)
  print(segment_cat_plot)

# %% [markdown]
# ### Baseline Kmeans - Cluster label metrics

# %%
#Call the function
#Original dataset info:
#df_cleaned = df_model
#num_cols = numerical_features_for_scaling
#cat_cols = categorical_features_to_encode


if labels_kmeans_baseline is not None:
    cluster_analysis(
        df_cleaned=df_model,
        cluster_input_df=X,
        cluster_labels=labels_kmeans_baseline,
        num_cols=numerical_features_for_scaling,
        cat_cols=categorical_features_to_encode,
        model_name="Baseline K-Means"
    )
else:
    print("KMeans did not produce labels for k=3.")
# Out:
# Cluster analysis for Baseline K-Means
# Cluster Sizes:
# Cluster_Label
# 0    19739
# 1       42
# 2        7
# Name: count, dtype: int64
# Cluster segment:
#                TotalTransactionValue  TotalItemsInTransaction  \
# Cluster_Label
# 0                        3088.025694               274.923654
# 1                        3842.918333               227.595238
# 2                        1028.671429                 1.571429
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# Cluster_Label
# 0                                26.129541                  12.710112
# 1                                25.452381                  86.556313
# 2                                 1.142857                 655.897143
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction
# Cluster_Label
# 0                               9.492977                  19.247578
# 1                              24.435952                 596.955714
# 2                             651.174286                 660.620000
# TransactionIsWeekend      0     1
# Cluster_Label
# 0                      88.9  11.1
# 1                      83.3  16.7
# 2                     100.0   0.0

# %% [markdown]
# ### Baseline PCA + Kmeans - Cluster label metrics

# %%
cluster_analysis(
  df_cleaned= df_model,
  cluster_input_df = X,
  cluster_labels= labels_kmeans,
  num_cols=numerical_features_for_scaling,
  cat_cols=categorical_features_to_encode,
  model_name="PCA + K-Means (Baseline)")
# Out:
# Cluster analysis for PCA + K-Means (Baseline)
# Cluster Sizes:
# Cluster_Label
# 0    19394
# 1      340
# 2       54
# Name: count, dtype: int64
# Cluster segment:
#                TotalTransactionValue  TotalItemsInTransaction  \
# Cluster_Label
# 0                        2508.578722               223.824327
# 1                       36182.322941              3193.711765
# 2                        3144.016667               177.351852
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# Cluster_Label
# 0                                23.158142                  12.674858
# 1                               195.991176                  12.390682
# 2                                20.037037                 168.194725
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction
# Cluster_Label
# 0                               9.482677                  19.068547
# 1                               7.702853                  27.225500
# 2                             119.266667                 565.784259
# TransactionIsWeekend     0     1
# Cluster_Label
# 0                     88.8  11.2
# 1                     91.5   8.5
# 2                     87.0  13.0

# %% [markdown]
# ### Baseline Autoencoder + Kmeans - Cluster label metrics

# %%
cluster_analysis(
  df_cleaned= df_model,
  cluster_input_df = X,
  cluster_labels= labels_autoencoder_kmeans ,
  num_cols=numerical_features_for_scaling,
  cat_cols=categorical_features_to_encode,
  model_name="Autoencoder + K-Means (Baseline)")
# Out:
# Cluster analysis for Autoencoder + K-Means (Baseline)
# Cluster Sizes:
# Cluster_Label
# 0    17097
# 1     1391
# 2     1300
# Name: count, dtype: int64
# Cluster segment:
#                TotalTransactionValue  TotalItemsInTransaction  \
# Cluster_Label
# 0                        3074.694684               272.870153
# 1                        3527.688994               318.619698
# 2                        2806.209262               252.174615
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# Cluster_Label
# 0                                26.134351                  13.176911
# 1                                24.267434                  12.364719
# 2                                27.902308                  12.789678
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction
# Cluster_Label
# 0                               9.787395                  20.939160
# 1                               9.431812                  19.132768
# 2                               9.624346                  19.241485
# TransactionIsWeekend      0      1
# Cluster_Label
# 0                      94.7    5.3
# 1                     100.0    0.0
# 2                       0.0  100.0

# %% [markdown]
# ### Finetuned PCA + Kmeans

# %%
cluster_analysis(
  df_cleaned= df_model,
  cluster_input_df = X,
  cluster_labels= cluster_labels_pca_ft,
  num_cols=numerical_features_for_scaling,
  cat_cols=categorical_features_to_encode,
  model_name="PCA + K-Means (Finetuned)")
# Out:
# Cluster analysis for PCA + K-Means (Finetuned)
# Cluster Sizes:
# Cluster_Label
# 0    19742
# 1       39
# 2        7
# Name: count, dtype: int64
# Cluster segment:
#                TotalTransactionValue  TotalItemsInTransaction  \
# Cluster_Label
# 0                        3087.588366               274.882028
# 1                        4122.364359               245.025641
# 2                        1028.671429                 1.571429
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# Cluster_Label
# 0                                26.125722                  12.740111
# 1                                27.333333                  77.051414
# 2                                 1.142857                 655.897143
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction
# Cluster_Label
# 0                               9.523464                  19.276583
# 1                              10.152564                 626.712308
# 2                             651.174286                 660.620000
# TransactionIsWeekend      0     1
# Cluster_Label
# 0                      88.9  11.1
# 1                      84.6  15.4
# 2                     100.0   0.0

# %% [markdown]
# ### Finetuned Autoencoder + Kmeans

# %%
cluster_analysis(
  df_cleaned= df_model,
  cluster_input_df = X,
  cluster_labels= labels_ae_shallow,
  num_cols=numerical_features_for_scaling,
  cat_cols=categorical_features_to_encode,
  model_name="Autoencoder + K-Means (Finetuned)")
# Out:
# Cluster analysis for Autoencoder + K-Means (Finetuned)
# Cluster Sizes:
# Cluster_Label
# 0     10988
# 1       913
# 2      1161
# 3         7
# 4        39
# 5      1363
# 6      1017
# 7        29
# 8       156
# 9      1402
# 10       14
# 11      203
# 12     1270
# 13     1226
# Name: count, dtype: int64
# Cluster segment:
#                TotalTransactionValue  TotalItemsInTransaction  \
# Cluster_Label
# 0                        2469.440144               219.132053
# 1                        2572.095630               231.487404
# 2                        2504.030189               226.270457
# 3                        1028.671429                 1.571429
# 4                        4122.364359               245.025641
# 5                        2472.755767               224.913426
# 6                        2598.682114               223.963618
# 7                      110737.611034              9854.931034
# 8                       14034.385385              1209.602564
# 9                        2498.367397               224.581312
# 10                        282.602143                 2.142857
# 11                      36136.111281              3226.433498
# 12                       2530.081039               224.924409
# 13                       2525.266868               228.807504
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# Cluster_Label
# 0                                22.802330                  12.649002
# 1                                25.284775                  12.633048
# 2                                24.124892                  12.525455
# 3                                 1.142857                 655.897143
# 4                                27.333333                  77.051414
# 5                                20.867938                  12.524430
# 6                                22.680433                  12.894252
# 7                                64.241379                  11.951418
# 8                               421.160256                  12.746456
# 9                                22.698288                  12.755425
# 10                                1.000000                 151.550714
# 11                               42.428571                  12.034584
# 12                               21.816535                  12.705818
# 13                               21.939641                  12.519162
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction
# Cluster_Label
# 0                               9.420226                  18.800839
# 1                               9.147404                  22.710526
# 2                               9.266064                  19.130741
# 3                             651.174286                 660.620000
# 4                              10.152564                 626.712308
# 5                               9.778004                  17.841056
# 6                               9.515988                  19.039853
# 7                               7.295517                  20.313448
# 8                               6.146218                  39.574295
# 9                               9.530514                  20.594501
# 10                            151.550714                 151.550714
# 11                              8.825123                  19.501724
# 12                              9.664827                  18.446024
# 13                              9.517480                  18.111843
# TransactionIsWeekend      0     1
# Cluster_Label
# 0                     100.0   0.0
# 1                       2.6  97.4
# 2                     100.0   0.0
# 3                     100.0   0.0
# 4                      84.6  15.4
# 5                      99.8   0.2
# 6                     100.0   0.0
# 7                      93.1   6.9
# 8                      84.0  16.0
# 9                      99.9   0.1
# 10                     92.9   7.1
# 11                     94.6   5.4
# 12                      0.2  99.8
# 13                    100.0   0.0

# %% [markdown]
# Deep Autoencoder + Kmeans

# %%
cluster_analysis(
  df_cleaned= df_model,
  cluster_input_df = X,
  cluster_labels= labels_ae_deep,
  num_cols=numerical_features_for_scaling,
  cat_cols=categorical_features_to_encode,
  model_name="Deep Autoencoder + Kmeans")
# Out:
# Cluster analysis for Deep Autoencoder + Kmeans
# Cluster Sizes:
# Cluster_Label
# 0    19742
# 1       39
# 2        7
# Name: count, dtype: int64
# Cluster segment:
#                TotalTransactionValue  TotalItemsInTransaction  \
# Cluster_Label
# 0                        3087.588366               274.882028
# 1                        4122.364359               245.025641
# 2                        1028.671429                 1.571429
#
#                UniqueProductsInTransaction  AvgItemPriceInTransaction  \
# Cluster_Label
# 0                                26.125722                  12.740111
# 1                                27.333333                  77.051414
# 2                                 1.142857                 655.897143
#
#                MinItemPriceInTransaction  MaxItemPriceInTransaction
# Cluster_Label
# 0                               9.523464                  19.276583
# 1                              10.152564                 626.712308
# 2                             651.174286                 660.620000
# TransactionIsWeekend      0     1
# Cluster_Label
# 0                      88.9  11.1
# 1                      84.6  15.4
# 2                     100.0   0.0
